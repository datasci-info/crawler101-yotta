# %%
import urllib

# %%
encoded_url = "https://tw.news.yahoo.com/%E4%BB%8A%E5%B9%B4%E7%AC%AC9%E8%99%9F%E9%A2%B1%E9%A2%A8%E3%80%8C%E5%B0%BC%E8%8E%8E%E3%80%8D%E5%BD%A2%E6%88%90-%E5%91%A8%E6%9C%AB%E6%81%90%E5%BD%B1%E9%9F%BF%E5%8F%B0%E7%81%A3-060226531.html"

# %%
urllib.parse.unquote(encoded_url)
# Out:
# 'https://tw.news.yahoo.com/今年第9號颱風「尼莎」形成-周末恐影響台灣-060226531.html'

# %%
decoded_url = urllib.parse.unquote(encoded_url)
urllib.parse.quote(decoded_url)
# Out:
# 'https%3A//tw.news.yahoo.com/%E4%BB%8A%E5%B9%B4%E7%AC%AC9%E8%99%9F%E9%A2%B1%E9%A2%A8%E3%80%8C%E5%B0%BC%E8%8E%8E%E3%80%8D%E5%BD%A2%E6%88%90-%E5%91%A8%E6%9C%AB%E6%81%90%E5%BD%B1%E9%9F%BF%E5%8F%B0%E7%81%A3-060226531.html'

# %%
urllib.parse.quote(decoded_url).replace("%3A",":") == encoded_url
# Out:
# True

# %%
urllib.parse.quote(' !"#$%')
# Out:
# '%20%21%22%23%24%25'

# %%
urllib.parse.quote('中文')
# Out:
# '%E4%B8%AD%E6%96%87'

# %%
"中文".encode("utf8")
# Out:
# b'\xe4\xb8\xad\xe6\x96\x87'

# %%
import requests

# %%
res = requests.get(encoded_url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html><html id="atomic" class="NoJs lightweight smartphone" lang="zh-Hant-TW"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><meta name="msapplication-TileColor" content="#6e329d"/><meta name="msapplication-TileImage" content="https://s.yimg.com/os/mit/media/p/presentation/images/icons/win8-tile-1484740.png"/><meta name="referrer" content="origin"/><meta name="theme-color" content="#400090"/><meta name="twitter:dnt" content="on"/><meta name="twitter:site" content="@Yahoo"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="apple-itunes-app" content="app-id=304158842,app-argument=yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta name="twitter:image" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta name="twitter:image:src" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta name="twitter:title" content="今年第9號颱風「尼莎」形成 周末恐影響台灣"/><meta name="description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta property="og:type" content="article"/><meta property="fb:pages" content="109249609124014"/><meta property="fb:app_id" content="1402585510021694"/><meta property="al:android:app_name" content="Yahoo"/><meta property="al:android:package" content="com.yahoo.mobile.client.android.yahoo"/><meta property="al:android:url" content="yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta property="al:ios:app_name" content="Yahoo"/><meta property="al:ios:app_store_id" content="304158842"/><meta property="al:ios:url" content="yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta property="og:image:width" content="744"/><meta property="og:image:height" content="545"/><meta property="og:description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta property="og:image" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta property="og:title" content="今年第9號颱風「尼莎」形成 周末恐影響台灣"/><meta property="og:url" content="https://tw.news.yahoo.com/%E4%BB%8A%E5%B9%B4%E7%AC%AC9%E8%99%9F%E9%A2%B1%E9%A2%A8%E3%80%8C%E5%B0%BC%E8%8E%8E%E3%80%8D%E5%BD%A2%E6%88%90-%E5%91%A8%E6%9C%AB%E6%81%90%E5%BD%B1%E9%9F%BF%E5%8F%B0%E7%81%A3-060226531.html"/><meta http-equiv="x-dns-prefetch-control" content="on"/><link rel="dns-prefetch" href="//s.yimg.com"/><link rel="dns-prefetch" href="//geo.query.yahoo.com"/><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"/><link rel="dns-prefetch" href="//beap.gemini.yahoo.com"/><link rel="dns-prefetch" href="//yep.video.yahoo.com"/><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"/><link rel="dns-prefetch" href="//yrtas.btrll.com"/><link rel="dns-prefetch" href="//shim.btrll.com"/><link rel="preconnect" href="//s.yimg.com"/><link rel="preconnect" href="//geo.query ...

# %%
res = requests.get(decoded_url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html><html id="atomic" class="NoJs lightweight smartphone" lang="zh-Hant-TW"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark(\'PageStart\');</script><meta charset="utf-8"/><meta name="msapplication-TileColor" content="#6e329d"/><meta name="msapplication-TileImage" content="https://s.yimg.com/os/mit/media/p/presentation/images/icons/win8-tile-1484740.png"/><meta name="referrer" content="origin"/><meta name="theme-color" content="#400090"/><meta name="twitter:dnt" content="on"/><meta name="twitter:site" content="@Yahoo"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="apple-itunes-app" content="app-id=304158842,app-argument=yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta name="twitter:image" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta name="twitter:image:src" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta name="twitter:title" content="今年第9號颱風「尼莎」形成 周末恐影響台灣"/><meta name="description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta property="og:type" content="article"/><meta property="fb:pages" content="109249609124014"/><meta property="fb:app_id" content="1402585510021694"/><meta property="al:android:app_name" content="Yahoo"/><meta property="al:android:package" content="com.yahoo.mobile.client.android.yahoo"/><meta property="al:android:url" content="yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta property="al:ios:app_name" content="Yahoo"/><meta property="al:ios:app_store_id" content="304158842"/><meta property="al:ios:url" content="yahoo://article/view?uuid=ef30e516-2ef6-3f30-8093-acc2f1eead69&amp;amp;src=web"/><meta property="og:image:width" content="744"/><meta property="og:image:height" content="545"/><meta property="og:description" content="中央氣象局表示，位在菲律賓附近海面的熱帶性低氣壓，今天下午2時發展為今年第9號颱風尼莎，目前強度為輕颱，後續是否影響台灣還要再觀察。"/><meta property="og:image" content="https://s.yimg.com/ny/api/res/1.2/1An2bGA8j4Rm2vuAj4TZLA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyODA7aD05MzcuNjM0NDA4NjAyMTUwNQ--/https://s.yimg.com/uu/api/res/1.2/z9fhHaE3TdJJXT1YrH9O.g--~B/aD01NDU7dz03NDQ7c209MTthcHBpZD15dGFjaHlvbg--/http://media.zenfs.com/en/homerun/feed_manager_auto_publish_494/c335e7ed882f4e1904f74f644e5c7cb4"/><meta property="og:title" content="今年第9號颱風「尼莎」形成 周末恐影響台灣"/><meta property="og:url" content="https://tw.news.yahoo.com/%E4%BB%8A%E5%B9%B4%E7%AC%AC9%E8%99%9F%E9%A2%B1%E9%A2%A8%E3%80%8C%E5%B0%BC%E8%8E%8E%E3%80%8D%E5%BD%A2%E6%88%90-%E5%91%A8%E6%9C%AB%E6%81%90%E5%BD%B1%E9%9F%BF%E5%8F%B0%E7%81%A3-060226531.html"/><meta http-equiv="x-dns-prefetch-control" content="on"/><link rel="dns-prefetch" href="//s.yimg.com"/><link rel="dns-prefetch" href="//geo.query.yahoo.com"/><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"/><link rel="dns-prefetch" href="//beap.gemini.yahoo.com"/><link rel="dns-prefetch" href="//yep.video.yahoo.com"/><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"/><link rel="dns-prefetch" href="//yrtas.btrll.com"/><link rel="dns-prefetch" href="//shim.btrll.com"/><link rel="preconnect" href="//s.yimg.com"/><link rel="preconnect" href="//geo.query ...
