# %%
import requests

# %%
url = "http://emap.pcsc.com.tw/EMapSDK.aspx"

# %%
post_data = {
    "commandid":"SearchStore"
    ,"city":"台北市"
    ,"town":"大安區"
}

# %%
res = requests.post(url, data=post_data)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<?xml version="1.0" encoding="utf-8"?><iMapSDKOutput><MessageID>00000</MessageID><CommandID>SearchStore</CommandID><Status>連線成功</Status><TimeStamp>2018/2/1 上午 01:11:40</TimeStamp><GeoPosition><POIID>153319              </POIID><POIName>大台</POIName><X>121532614.37826</X><Y>25017959.8345753</Y><Telno>(02)23636229        </Telno><FaxNo>(02)23660784        </FaxNo><Address>台北市大安區羅斯福路3段283巷14弄16號1樓</Address><isDining>Y</isDining><isParking>N</isParking><isLavatory>N</isLavatory><isATM>Y</isATM><is7WiFi>Y</is7WiFi><isIce>N</isIce><isHotDog>N</isHotDog><isHealthStations>N</isHealthStations><isIceCream>N</isIceCream><isOpenStore>N</isOpenStore><isFruit>N</isFruit><isCityCafe>Y</isCityCafe><isUnionPay>N</isUnionPay><isOrganic>N</isOrganic><isCorn>N</isCorn><isMakeup>N</isMakeup><isMuji>N</isMuji><isMisterDonuts>N</isMisterDonuts><isStarBucks>N</isStarBucks><isIbon>Y</isIbon><isTea>N</isTea><isSweetPotato>N</isSweetPotato><isVitalityHealth>N</isVitalityHealth><isKidRoom>N</isKidRoom><isKanton
# ...
