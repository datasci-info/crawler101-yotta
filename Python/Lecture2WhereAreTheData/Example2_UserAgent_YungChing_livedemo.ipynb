# %%
import requests

# %%
url = "http://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter/"

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html><html> <head> <title>永慶房產集團</title> <meta http-equiv="Content-Type" content="text/html; charset=utf-8"> <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0"/> <meta name="description" content="永慶房產集團"/> <link rel="stylesheet" type="text/css" href="//cdncore.housefun.com.tw/RESWeb/firewall_assets/style.css"/> </head> <body class="is-yc"> <header> <h1>永慶房產集團</h1> </header> <div class="m-content"> <div class="m-section"> <h2>很抱歉</h2> <p> <span class="title">我們發現您的IP有些狀況，因此暫時無法為您開啟網頁。</span>如持續出現此狀況，請與我們聯繫並提供以下資訊，謝謝！ <span class="mail"><span>客服信箱</span> <a href="mailto:service1@yungching.com.tw?subject=無法開啟網頁，請確認我的IP狀態">service1@yungching.com.tw</a></span> </p></div></div><footer> <dl> <dt>時 間</dt> <dd class="date">2016/01/01 11:11:11</dd> <dt>錯 誤 代 碼</dt> <dd>8313692706704887107</dd> <dt>Session ID</dt> <dd>N/A</dd> <dt>I P</dt> <dd class="ip">127.0.0.1</dd> <dt>URL</dt> <dd class="url"></dd> </dl> </footer> </body> <script src="//cdncore.housefun.com.tw/RESWeb/firewall_assets/getdetail.js"></script><script src="fwb/df_lib.js"></script><script>var fp=new fingerprint,df_id,stable_df_id,post_details=0;fp.isUAMac()||fp.isUAMobile()?(post_details=1,stable_df_id=df_id=2):(post_details=1,df_id=0);postItems();function postItems(){if(0!=post_details){0==df_id&&(df_id=fp.getFingerprint().MD5,stable_df_id=fp.getFingerprint().Stable_MD5);var b=fp.getPostItems();b.df_id=df_id;b.stable_df_id=stable_df_id;post("/fwb/first_submit.df",b)}}\nfunction post(b,d){var a;a=window.XMLHttpRequest?new XMLHttpRequest:new ActiveXObject("Microsoft.XMLHTTP");a.onreadystatechange=function(){4==a.readyState&&200==a.status&&eval(a.responseText)};a.open("POST",b,!0);a.setRequestHeader("Content-type","application/x-www-form-urlencoded");var e="",c;for(c in d)value=c+"="+encodeURIComponent(d[c])+"&",e+=value;a.send(e)};</script>\n</html>'

# %%
res.headers
# Out:
# {'Content-Type': 'text/html; charset=UTF-8', 'Cache-Control': 'no-cache', 'Pragma': 'no-cache', 'Expires': '0', 'Connection': 'close', 'Set-Cookie': 'cookiesession1=68C4953ETEL3CWOVIFRH84URRNZYC1B4;Path=/;HttpOnly', 'content-length': '2107'}

# %%
res.request.headers
# Out:
# {'User-Agent': 'python-requests/2.18.4', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
hs = {
    "user-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.76 Safari/537.36"
}

# %%
res = requests.get(url, headers=hs)

# %%
res
# Out:
# <Response [200]>

# %%
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <!--[if lte IE 8]>    <html class="no-js lt-ie9" lang="zh-Hant-TW" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html dir="ltr" lang="zh-Hant-TW" itemscope itemtype="http://schema.org" >
# <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" >
#     <meta charset="UTF-8">
#     <title> 台北市買屋、購屋、買房子、找房屋 | 永慶房仲網買屋</title>
#
#     <meta name="description" content="買屋、購屋、買房子、找房屋首選永慶房仲網，網羅 台北市-  新成屋、中古屋、社區、住宅等房屋仲介資訊，還有線上影音看屋、成交行情，讓買屋更輕鬆。" />
#     <meta property="fb:app_id" content="320559141361882" />
#     <meta property="og:locale" content="zh_TW" />
#     <meta property="og:title" itemprop="name" content=" 台北市買屋、購屋、買房子、找房屋 | 永慶房仲網買屋" />
#     <meta property="og:description" content="買屋、購屋、買房子、找房屋首選永慶房仲網，網羅 台北市-  新成屋、中古屋、社區、住宅等房屋仲介資訊，還有線上影音看屋、成交行情，讓買屋更輕鬆。" />
#     <meta property="og:url" itemprop="url" content="https://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter" />
#     <meta property="og:image" itemprop="image" content="https://buy.yungching.com.tw/Content/img/FB-400x300.png" />
#     <meta property="og:site_name" content="永慶房仲網" />
#     <link rel="canonical" href="https://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter" />
#     <link href="//s1.hfcdn.com/min/b=fp&f=common/font-awesome/css/font-awesome.min.css,hf/libs/cirobox/css/cirobox.css&v=C2015073001" rel="stylesheet">
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-60x60.png" sizes="57x57" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-76x76.png" sizes="72x72" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-120x120.png" sizes="114x114" />
#     <link rel="apple-touch-icon" href="/Content/img/apple-icon-152x152.png" sizes="144x144" />
#
#
#         <link href="/content/bcss/searchcss?v=rTNhdOvFrSMrcNXAj1ViKwQSs-Al_CyYniLHnB_BRb81" rel="stylesheet"/>
#
#
#     <script type="text/javascript" src="/Scripts/libs/modernizr_custom.js"></script>
#     <script type="text/javascript" src="//admd.yungching.com.tw/AD.aspx"></script>
#     <script src="//ecrmtr.housefun.com.tw/web_service/common/getWmxC.aspx"></script>
#
#
#     <script type="text/javascript">
#     var ltm_data = {
#         url: "http://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter/",
#         pagetype: "house_area_serach_result",
#         pageversion: "web",
#         member_token: "",
#         trid: "9db9a448-4c23-45a1-a9fc-a67378013997",
#         ltm: {
#             source: "",
#             campaign: "",
#             medium: "",
#             term: "",
#             content: "",
#         },
#         pagedata: {
#             areas: [{city:"台北市",district:""}],
#             total_price_start: "",
#             total_price_end: "",
#             price_start: "",
#             price_end: "",
#             pin_start: "",
#             pin_end: "",
#             room_start: "",
#             room_end: "",
#             age_start: "",
#             age_end: "",
#             floor_start: "",
#             floor_end: "",
#             purpose: [],
#             type: [],
#             direction: [],
#             label: ["降價"],
#             parking_space: "",
#             barrier_free: "",
#             keyword: "",
#             brand:[1]
#         },
#         list_ids:["2206024","2502216","2149601","2922447","2779707","2916720","2803498","2810670","2376664","2843036","2221798","2725313","2801861","2918742","2686074","2393236","2709138","2780971","2616503","2600266"]
#     }
# </script>
#
#
#
#     <!--[if lte IE 8]> <script> if( parseInt(document.documentMode, 10) < 8 ){ window.location.replace('//www.yungching.com.tw/nosupport.html'); } </script> <![endif]-->
#
# </head>
#
# <body ng-app="ycapp">
#     <!-- Google Tag Manager -->
#     <noscript>
#         <iframe src="//www.googletagmanager.com/ns.html?id=GTM-PKJHNQ"
#                 height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     </noscript>
#     <script>var VID = '';</script>
#     <script>
#         (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#         new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#         '//www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-PKJHNQ');
#     </script>
#     <!-- End Google Tag Manager -->
#
# <link rel="stylesheet" type="text/css" href="//s1.hfcdn.com/min/b=fp/yc_common&f=header.css&v=20180123001">
# <header class="l-header">
#     <div class="m-header-bar">
#         <ul class="m-header-bar-bd">
#             <li class="header-marquee-wrap">
#                 <ul class="header-marquee-bd">
#                     <li><a target='_blank' href='http://www.chinatimes.com/newspapers/20160711000097-260204' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_〈工商時報報導〉永慶用創新擄獲年輕世代，期待「不一樣的你」！_BUY'>〈工商時報報導〉永慶用創新擄獲年輕世代，期待「不一樣的你」！</a></li><li><a target='_blank' href='http://www.chinatimes.com/newspapers/20160711000093-260204' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_〈工商時報報導〉永慶房屋4連霸。市場不景氣，越能突顯永慶的威力！_BUY'>〈工商時報報導〉永慶房屋4連霸。市場不景氣，越能突顯永慶的威力！</a></li><li><a target='_blank' href='http://market.ltn.com.tw/news.php?no=1032' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_〈自由時報報導〉永慶孫慶餘推動i+智慧經紀人，徹底翻轉工作型態！_BUY'>〈自由時報報導〉永慶孫慶餘推動i+智慧經紀人，徹底翻轉工作型態！</a></li><li><a target='_blank' href='http://www.gvm.com.tw/webonly_content_8835.html' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_〈遠見雜誌報導〉永慶孫慶餘大膽創新，引領台灣房仲業向上提升。_BUY'>〈遠見雜誌報導〉永慶孫慶餘大膽創新，引領台灣房仲業向上提升。</a></li><li><a target='_blank' href='http://www.cw.com.tw/article/article.action?id=5075622' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_〈天下雜誌報導〉永慶孫慶餘打造10年成長25倍的「永慶傳奇」_BUY'>〈天下雜誌報導〉永慶孫慶餘打造10年成長25倍的「永慶傳奇」</a></li><li><a target='_blank' href='//news.housefun.com.tw/news/article/401881125569.html' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_孫慶餘董事長：房仲「規模」決定生存空間，形成無法超越的「永慶障礙」_BUY'>孫慶餘董事長：房仲「規模」決定生存空間，形成無法超越的「永慶障礙」</a></li><li><a target='_blank' href='http://www.chinatimes.com/realtimenews/20160204002537-260405' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_永慶房屋多箭齊發 2016年逆勢拚市佔三成_BUY'>永慶房屋多箭齊發 2016年逆勢拚市佔三成</a></li><li><a target='_blank' href='//sell.yungching.com.tw' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_快售榮獲第16屆金手指網路獎「最佳使用者介面項-金獎」！_BUY'>快售榮獲第16屆金手指網路獎「最佳使用者介面項-金獎」！</a></li><li><a target='_blank' href='//buy.yungching.com.tw' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_買屋榮獲第16屆金手指網路獎「最佳使用者體驗項」佳作！_BUY'>買屋榮獲第16屆金手指網路獎「最佳使用者體驗項」佳作！</a></li><li><a target='_blank' href='//sell.yungching.com.tw' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_快售服務榮獲2015資訊月「百大創新產品獎」_BUY'>快售服務榮獲2015資訊月「百大創新產品獎」</a></li><li><a target='_blank' href='//www.yungching.com.tw/CF/CF16.asp?Pkey=%7B934269F8-B20D-4A84-B296-E37E61E4984B%7D' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_2015永慶獲Young世代愛用！四度勇奪房仲品牌第一名！_BUY'>2015永慶獲Young世代愛用！四度勇奪房仲品牌第一名！</a></li><li><a target='_blank' href='//www.yungching.com.tw/CF/CF16.asp?Pkey=%7B06EC0FBE-9619-4838-84EA-172BFA437530%7D' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_2015永慶「房仲科技3.0」創新獲邀參與國家級展覽_BUY'>2015永慶「房仲科技3.0」創新獲邀參與國家級展覽</a></li><li><a target='_blank' href='//www.yungching.com.tw/CF/CF16.asp?Pkey=%7B6DEB3D51-8F7B-4345-8CDB-B1BBD70AB13E%7D' class='ga_click_trace' ga_cat='header' ga_event='click' ga_label='header_ad_永慶榮獲服務獎大滿貫！遠見雜誌、天下雜誌、工商時報3大服務獎_BUY'>永慶榮獲服務獎大滿貫！遠見雜誌、天下雜誌、工商時報3大服務獎</a></li>
#                 </ul>
#             </li>
#                 <!-- 未登入 -->
#                 <li class="has-menu">
#                     <a href="//memberyc.yungching.com.tw/" title="註冊/登入" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_registerlogin_BUY">註冊/登入</a>
#                     <ul class="m-header-bar-sub">
#                         <li class="no-border"><a href="https://memberyc.yungching.com.tw/Account/SignUp?AFromURL=https://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter/" title="註冊會員" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_register_BUY">註冊會員</a></li>
#                         <li><a href="https://memberyc.yungching.com.tw/Account/Login?AFromURL=https://buy.yungching.com.tw/region/台北市-_c/pricereduction_filter/" t title="會員登入" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_login_BUY">會員登入</a></li>
#                         <li><a href="http://yctraderpt.yungching.com.tw//YCTradeRPT/" title="永慶房屋成交客戶專區" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_trademember_BUY">永慶房屋成交客戶專區</a></li>
#                     </ul>
#                 </li>
#             <!-- 未登入 end -->
#             <li><a href="//www.yungching.com.tw/app" title="App下載" target="_self" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_app_BUY"><i class="fa fa-mobile"></i> App下載</a></li>
#             <li><a href="//www.yungching.com.tw/iplus_store" title="i+智慧創新體驗館" target="_self" class="ga_click_trace" ga_cat="header" ga_event="click" ga_label="header_iplusstore_BUY">i+智慧創新體驗館</a></li>
#         </ul>
#     </div>
#     <div class="l-header-bd">
#         <div class="l-header-bd-content">
#             <a href="//www.yungching.com.tw" class="yc-logo ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_logo_BUY" title="永慶房仲網">永慶房仲網</a>
#             <nav class="m-header-nav">
#                 <ul class="m-yc-menu">
#                     <li class="is-active">
#                         <a href="//buy.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_buy_BUY">買屋</a>
#                         <ul class="m-yc-menu-sub">
#                             <li><a href="//buy.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_BUY">找房子</a></li>
#                             <li><a href="//buy.yungching.com.tw/map/region/" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_map_BUY">地圖找房</a></li>
#                             <li class="separation is-separation-bottom"><a href="//buy.yungching.com.tw/mrt/台北市-_c/" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_mrt_BUY">捷運找房</a></li>
#                             <li><a href="//buy.yungching.com.tw/region/台北市-_c/pricereduction_filter/" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_pricereduction_BUY">降價屋</a></li>
#                             <li class="separation is-separation-bottom"><a href="//topic.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_topic_BUY">買屋主題推薦</a></li>
#                             <li><a href="//msg.yungching.com.tw/Searching/Order?lightbox=1" class="openLightbox ga_click_trace ga_click_popup" data-cheight="818" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_message_BUY">買屋需求留言</a></li>
#                             <li><a href="//knowhow.yungching.com.tw/knowledge-buy?nv1=buyR&amp;nv2=knowledgebuy" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_knowledge_BUY">買屋知識</a></li>
#                             <li><a href="//knowhow.yungching.com.tw/tool/loaninterest?nv1=toolR&amp;nv2=loaninterest" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_buy_loaninterest_BUY">房貸試算</a></li>
#                         </ul>
#                     </li>
#                     <li class="">
#                         <a href="//sell.yungching.com.tw/myplace" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sell_BUY">快售</a>
#                         <ul class="m-yc-menu-sub">
#                             <li><a href="//sell.yungching.com.tw/myplace" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_sell_myplace_BUY">賣屋算算看</a></li>
#                             <li class="separation is-separation-bottom"><a href="//msg.yungching.com.tw/Advisory/Valuation?lightbox=1" class="openLightbox ga_click_trace ga_click_popup" data-cheight="628" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_sell_message_BUY">免費房價諮詢留言</a></li>
#                             <li><a href="//knowhow.yungching.com.tw/knowledge-sell?nv1=sellR&amp;nv2=knowledgesell" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_sell_knowledge_BUY">賣屋知識</a></li>
#                             <li><a href="//knowhow.yungching.com.tw/article/756?nv1=sellR&amp;nv2=selltax" class="ga class=" ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_sell_taxtool_BUY">稅費試算</a></li>
#                             <li><a href="//knowhow.yungching.com.tw/tool/floormap?nv1=toolR&amp;nv2=floormap" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_sub_sell_floormap_BUY">格局圖工具</a></li>
#                         </ul>
#                     </li>
#                     <li class="">
#                         <a href="//community.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_community_BUY">社區</a>
#                     </li>
#                     <li class="">
#                         <a href="//evertrust.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_evertrust_BUY">行情</a>
#                     </li>
#                     <li class="">
#                         <a href="http://rent.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_rent_BUY">租屋</a>
#                     </li>
#                     <li class="">
#                         <a href="//shop.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_shop_BUY">門市</a>
#                     </li>
#                     <li class="">
#                         <a href="//knowhow.yungching.com.tw" class="ga_click_trace" ga_cat="topmenu" ga_event="click" ga_label="topmenu_knowhow_BUY">知識</a>
#                     </li>
#                 </ul>
#             </nav>
#         </div> <!-- head-wrap -->
#     </div>
#     <input type="hidden" id="hiddentopclid" name="hiddentopclid" value="" />
# </header>
#
#
#
#
#
#
# <main class="l-body" ng-controller="searchCtrl" ng-cloak>
#
#     <!-- 搜尋區塊 -->
#     <div class="ng-search-bar">
# 	<ul class="m-search-for-lists">
# 	  <li ga-buy-search ga-label="buy_search_{{ i.name }}" ga-event="buy_search_{{ i.name }}_click" ga-cat="buy_search"
# 		  ng-repeat="i in ::searchFor" ng-class="{'is-active': i.key == searchCondition.searchFor}"
# 		  ng-click="changeSearchCondition(i.key, true);" >{{ i.name }}</li>
# 	</ul>
#
# <div class="m-search-field">
#   <div class="m-search-select-wrap">
#     <a href class="search-select-curr" ga-buy-search ga-label="buy_search_%%_how" ga-event="buy_search_%%_how_click" ga-cat="buy_search">
#       <i ng-class="mainSelectOption.icon"></i> <span>{{ mainSelectOption.name }}</span>
#     </a>
#     <ul class="search-select-option">
#       <li><a ga-buy-search ga-label="buy_search_%%_how_area" ga-event="buy_search_%%_how_click" ga-cat="buy_search" ng-click="mainSelect(0)" class="active" href><i class="pre fa fa-check-circle"></i> <i class="fa fa-bars"></i> 區域找</a></li>
#       <li><a ga-buy-search ga-label="buy_search_%%_how_mrt" ga-event="buy_search_%%_how_click" ga-cat="buy_search" ng-click="mainSelect(1)" href><i class="pre fa fa-circle-o"></i> <i class="i-mrt"></i> 捷運找</a></li>
#     </ul>
#   </div>
#
#   <!-- 捷運 -->
#   <div ng-show="mainSelectOption.key == 'mrt'" class="m-search-select-wrap">
#     <a href="#" class="search-select search-select-mrt">
#       <span ng-show="searchCondition.addr[0][0] != '高雄市'">台北</span><span ng-show="searchCondition.addr[0][0] == '高雄市'">高雄</span>捷運
#       </a>
#     <div class="search-select-option-mrt select-option">
#       <div class="label"><a href ng-click="changeMrtMap('台北市')">台北捷運 </i></a></div>
#       <div class="label kh"><a href ng-click="changeMrtMap('高雄市');">高雄捷運 </i></a></div>
#     </div>
#   </div>
#   <!-- 捷運 -->
#
#   <!-- 縣市/鄉鎮市區 -->
#   <div ng-hide="mainSelectOption.key == 'mrt'" class="m-search-select-wrap">
#     <a href class="search-select search-select-city" ga-buy-search ga-label="buy_search_%%_location" ga-event="buy_search_%%_location_click" ga-cat="buy_search">{{ limitStr(searchCondition.addr) }}</a>
#     <div class="search-select-option-cities select-option">
#       <a href class="close">&times;</a>
#       <ul>
#         <!-- 縣市 -->
#         <li ng-show="isCitySelection" ng-repeat="c in cities">
#           <a ng-click="toggleAreaSelect($index);" href ga-buy-search ga-label="buy_search_%%_location_{{ c }}" ga-event="buy_search_%%_location_click" ga-cat="buy_search">{{ c }}</a>
#         </li>
#
#         <!-- 鄉鎮區域 -->
#         <li class="reset" ng-hide="isCitySelection">
#           <a ga-buy-search ga-label="buy_search_%%_location_reset" ga-event="buy_search_%%_location_click" ga-cat="buy_search" href ng-click="isCitySelection = true;">重選縣市</a>
#         </li>
#         <li ng-hide="isCitySelection" ng-repeat="a in areaList">
#           <label>
#             <input
# 				ga-buy-search ga-label="buy_search_%%_location_{{ searchCondition.addr[0] }}{{ a }}" ga-event="buy_search_%%_location_click" ga-cat="buy_search"
# 				area="{{ a }}" index="{{$index}}" type="checkbox" class="chkbox area-chkbox" ng-checked="selectedAreas.indexOf(a) > -1">
#             <span>{{ a }}</span>
#           </label>
#         </li>
#       </ul>
#     </div>
#   </div>
#
#   <div class="m-search-select-wrap">
#     <a href class="search-select search-select-price" ga-buy-search ga-label="buy_search_%%_price" ga-event="buy_search_%%_price_click" ga-cat="buy_search">{{ showRange('price') }}</a>
#     <div class="search-select-option-price select-option">
#       <label><input type="checkbox" index="-1" listtype="priceList" class="chkbox chkbox-any" chkbox-area ga-buy-search ga-label="buy_search_%%_price_none" ga-event="buy_search_%%_price_click" ga-cat="buy_search"><span>總價不限</span></label>
#       <label ng-repeat="i in currPriceList">
#         <input type="checkbox" index="{{$index}}" listtype="priceList" class="chkbox" chkbox-area
# 		ga-buy-search ga-label="buy_search_%%_price_{{ currPriceList[$index - 1] }}-{{ currPriceList[$index] }}" ga-event="buy_search_%%_price_click" ga-cat="buy_search">
#         <span ng-if=" $index == 0 ">{{ currPriceList[$index] }} 萬以下</span>
#         <span ng-if=" $index > 0 && $index < (currPriceList.length-1) ">{{ currPriceList[$index - 1] }} 萬 - {{ currPriceList[$index] }} 萬</span>
#         <span ng-if=" $index == (currPriceList.length - 1) ">{{ currPriceList[$index - 1] }} 萬以上</span>
#       </label>
#
#       <div class="custom-block">
#         <div class="input-wrap">
#           <input index="0" listtype="priceList" class="custom-num num" type="text" size="5"> -
#           <input index="1" listtype="priceList" class="custom-num num" type="text" size="5"> 萬
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <div class="m-search-select-wrap">
#     <a href class="search-select search-select-area" ga-buy-search ga-label="buy_search_%%_sqft" ga-event="buy_search_%%_sqft_click" ga-cat="buy_search">{{ showRange('pyeong') }}</a>
#     <div class="search-select-option-area select-option">
#       <div style="height: 40px; line-height: 40px; padding-left: 0.7em; margin-bottom: 0.2em; border-bottom: 1px solid #eee;">
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="1" name="pyeongType-type">
#           <span>{{ pyeongTypeText[1] }}</span>
#         </label>
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="2" name="pyeongType-type">
#           <span>{{ pyeongTypeText[2] }}</span>
#         </label>
#         <label class="inline">
#           <input class="sp-chkbox" type="radio" ng-model="searchCondition.pyeongType" value="0" name="pyeongType-type">
#           <span>{{ pyeongTypeText[0] }}</span>
#         </label>
#       </div>
#
#       <label><input type="checkbox" index="-1" listtype="pyeongList" class="chkbox chkbox-any" chkbox-area ga-buy-search ga-label="buy_search_%%_sqft_none" ga-event="buy_search_%%_sqft_click" ga-cat="buy_search"><span>坪數不限</span></label>
#       <label ng-repeat="i in pyeongList">
#         <input type="checkbox" index="{{$index}}" listtype="pyeongList" class="chkbox" chkbox-area
# 		 ga-buy-search ga-label="buy_search_%%_sqft_{{ pyeongList[$index - 1] }}-{{ pyeongList[$index] }}" ga-event="buy_search_%%_sqft_click" ga-cat="buy_search">
#         <span ng-if=" $index == 0">{{ pyeongList[$index] }} 坪以下</span>
#         <span ng-if=" $index > 0 && $index < (pyeongList.length-1) ">{{ pyeongList[$index - 1] }} 坪 - {{ pyeongList[$index] }} 坪</span>
#         <span ng-if=" $index == (pyeongList.length - 1) ">{{ pyeongList[$index - 1] }} 坪以上</span>
#       </label>
#
#       <div class="custom-block">
#         <div class="input-wrap">
#           <input index="0" listtype="pyeongList" class="custom-num num" type="text" size="3"> -
#           <input index="1" listtype="pyeongList" class="custom-num num" type="text" size="3"> 坪
#         </div>
#       </div>
#     </div>
#   </div>
#
#   <span class="m-search-input-wrap">
#     <input type="text" class="search-text-keywords" data-channel="buy" placeholder="編號、關鍵字、街道、大樓或學校"><button class="search-text-query" ga-buy-search ga-label="buy_search_%%_keyword_btn" ga-event="buy_search_%%_keyword_click" ga-cat="buy_search"><i class="fa fa-search fa-lg"></i></button>
#     <div class="search-keywords-ac select-option">
#       <ul>
#         <li ng-repeat="k in autoComplete" class="search-auto-complete"  data-keyword="{{ k.KEYWORD }}">
#           <div class="keyword-title">{{ k.KEYWORD }}</div>
#           <div class="keyword-count">約 {{ k.COUNT }} 間</div>
#         </li>
#       </ul>
#     </div>
#   </span>
#
#   <a ga-buy-search ga-label="buy_search_%%_more" ga-event="buy_search_%%_click" ga-cat="buy_search" href class="search-more-fliter-switcher">更多篩選({{ more_filter_counter() }})</a>
#   <a ga-buy-search ga-label="buy_search_%%_btn" ga-event="buy_search_%%_click" ga-cat="buy_search" href class="search-submit-btn">找房子</a>
# </div> <!-- m-search-field -->
#
# <!-- 更多篩選條件 -->
# <div class="m-search-more-filter-block">
#   <div class="search-filter-block-wrap">
#     <div class="col col-small">
#
#       <div class="chkbox-wrap">
#         <label ng-repeat="i in advConditions.houseType.val">
#         <input type="checkbox" class="chkbox" value="{{i}}" listtype="houseType" simple-chkbox
#           ng-checked="searchCondition.advConditions.houseType.indexOf(i) > -1"
# 		  ga-buy-search ga-label="buy_search_%%_type_{{ advConditions.houseType.gaLabel[$index] }}" ga-event="buy_search_%%_type_click" ga-cat="buy_search">
#         <span>{{ i }}</span></label>
#       </div>
#
#       <div class="chkbox-wrap sp">
#         <label ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'" ng-repeat="i in advConditions.car.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="car" simple-chkbox
#             ng-checked=" $index == 0 && searchCondition.advConditions.car[0] == 'true' || $index == 1 && searchCondition.advConditions.car[0] == 'false' "
# 			ga-buy-search ga-label="buy_search_%%_type_park_{{ advConditions.car.gaLabel[$index] }}" ga-event="buy_search_%%_park_click" ga-cat="buy_search">
#             <span>{{ i }}</span>
#         </label>
#       </div>
#
#       <div class="chkbox-wrap sp">
#         <label ng-hide="searchCondition.searchFor == 'earth'" ng-repeat="i in advConditions.accessible.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="accessible" simple-chkbox
# 			  ga-buy-search ga-label="buy_search_%%_accessible" ga-event="buy_search_%%_accessible_click" ga-cat="buy_search"
#               ng-checked="searchCondition.advConditions.accessible[0] == 'true' || searchCondition.advConditions.accessible[0] == true"> <span>{{ i }}</span>
#         </label>
#       </div>
#     </div>
#
#     <div class="col select-option" ng-hide="searchCondition.searchFor == 'earth'">
#
#       <label>
# 		<input type="checkbox" index="-1" listtype="houseAge" class="chkbox chkbox-any" chkbox-area
# 		 ga-buy-search ga-label="buy_search_%%_age_none" ga-event="buy_search_%%_age_click" ga-cat="buy_search"><span> 屋齡不限</span>
# 	  </label>
#       <label ng-repeat="i in advConditions.houseAge.val">
#         <input type="checkbox" index="{{$index}}" listtype="houseAge" class="chkbox" chkbox-area
# 		 ga-buy-search ga-label="buy_search_%%_age_{{ advConditions.houseAge.val[$index - 1] }}-{{ advConditions.houseAge.val[$index] }}" ga-event="buy_search_%%_age_click" ga-cat="buy_search">
#         <span ng-if=" $index == 0 ">{{ advConditions.houseAge.val[$index] }} 年以下</span>
#         <span ng-if=" $index > 0 && $index < (advConditions.houseAge.val.length-1) ">
#           {{ advConditions.houseAge.val[$index - 1] }} 年 - {{ advConditions.houseAge.val[$index] }} 年</span>
#         <span ng-if=" $index == (advConditions.houseAge.val.length - 1) ">{{ advConditions.houseAge.val[$index - 1] }} 年以上</span>
#       </label>
#       <div class="input-wrap">
#         <input index="0" listtype="houseAge" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="houseAge" class="custom-num num" type="text" size="2"> 年
#       </div>
#     </div>
#
#     <div class="col select-option" ng-hide="searchCondition.searchFor == 'earth'">
#       <label><input type="checkbox" index="-1" listtype="floors" class="chkbox chkbox-any" chkbox-area
# 	   ga-buy-search ga-label="buy_search_%%_floor_none" ga-event="buy_search_%%_floor_click" ga-cat="buy_search"><span> 樓層不限</span></label>
#
#       <label ng-repeat="i in advConditions.floors.val" ng-if="$index != 3 && $index != 5">
#         <input type="checkbox" index="{{$index}}" listtype="floors" class="chkbox" chkbox-area
# 		  ga-buy-search ga-label="buy_search_%%_floor_{{ advConditions.floors.val[$index] }}-{{ advConditions.floors.val[$index+1] }}" ga-event="buy_search_%%_floor_click" ga-cat="buy_search"
#           ng-checked="$index == advConditions.floors.val.length - 1 && searchCondition.advConditions.floors.sp[0] == 'true'"
#           ng-class="{ 'checkbox_sp' : $index == advConditions.floors.val.length - 1 }">
#
#         <span ng-if="$index == 0" data-min="0" data-max="0">低於 1 樓</span>
#
#         <span ng-if="$index == 1"
#           data-min="{{advConditions.floors.val[$index]}}"
#           data-max="{{advConditions.floors.val[$index]}}">
#           {{ advConditions.floors.val[$index] }} 樓</span>
#
#         <span ng-if="$index > 1 && $index < (advConditions.floors.val.length-2)"
#             data-min="{{ advConditions.floors.val[$index] }}"
#             data-max="{{ advConditions.floors.val[$index+1] }}">
#             {{ advConditions.floors.val[$index] }} - {{ advConditions.floors.val[$index+1] }} 樓</span>
#
#         <span ng-if="$index == advConditions.floors.val.length - 2"
#           data-min="{{ advConditions.floors.val[$index] }}"
#           data-max="99">{{ advConditions.floors.val[$index] }} 樓以上</span>
#
#         <span ng-if="$index == advConditions.floors.val.length - 1"> 頂樓</span>
#       </label>
#
#       <div class="input-wrap">
#         <input index="0" listtype="floors" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="floors" class="custom-num num" type="text" size="2"> 樓
#       </div>
#     </div>
#
#     <div class="col select-option" ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'">
#       <label><input type="checkbox" index="-1" listtype="rooms" class="chkbox chkbox-any" chkbox-area
# 	   ga-buy-search ga-label="buy_search_%%_room_none" ga-event="buy_search_%%_room_click" ga-cat="buy_search"><span> 房數不限</span></label>
#       <label ng-repeat="i in advConditions.rooms.val">
#         <input type="checkbox" index="{{$index}}" listtype="rooms" class="chkbox" chkbox-area
# 		ga-buy-search ga-label="buy_search_%%_room_{{ advConditions.rooms.val[$index] }}" ga-event="buy_search_%%_room_click" ga-cat="buy_search"
#         ng-checked="$index == advConditions.rooms.val.length - 1 && searchCondition.advConditions.rooms.sp[0] == 'true'"
#         ng-class="{ 'checkbox_sp' : $index == advConditions.rooms.val.length-1 }">
#         <span ng-if="$index < advConditions.rooms.val.length - 1 && $index != advConditions.rooms.val.length-2"> {{ advConditions.rooms.val[$index] }} 房</span>
#         <span ng-if="$index == advConditions.rooms.val.length-2"> {{ advConditions.rooms.val[$index] }} 房以上</span>
#         <span ng-if="$index == advConditions.rooms.val.length-1"> 含加蓋</span>
#       </label>
#       <div class="input-wrap">
#         <input index="0" listtype="rooms" class="custom-num num" type="text" size="2"> -
#         <input index="1" listtype="rooms" class="custom-num num" type="text" size="2"> 房
#       </div>
#     </div>
#
#     <div class="col col-small" ng-hide="searchCondition.searchFor == 'parking' || searchCondition.searchFor == 'earth'">
#       <div class="chkbox-wrap">
#         <label ng-repeat="i in advConditions.directions.val">
#           <input type="checkbox" class="chkbox" value="{{i}}" listtype="directions" simple-chkbox
#                  ng-checked="searchCondition.advConditions.directions.indexOf(i) > -1">
#           <span ng-if=" $index == 0 ">朝向{{ i }}</span>
#           <span ng-if=" $index > 0 ">{{ i }}</span>
#         </label>
#       </div>
#     </div>
#
#   </div>
# </div> <!-- .m-search-more-filter-block -->
#
# <!--  捷運地圖 -->
# <div ng-show="mainSelectOption.key == 'mrt'" class="mrt-map-handler-bar">
#   <a href class="mrt-map-handler on"></a>
# </div>
# <div ng-show="mainSelectOption.key == 'mrt'" class="m-mrt-map">
#   <div class="route-map">
#     <div class="mrt-stations-chkbox"
#          ng-class="{ 'tp-mrt-stations': searchCondition.addr[0][0] != '高雄市', 'kh-mrt-stations': searchCondition.addr[0][0] == '高雄市'}">
#       <span ng-show="searchCondition.addr[0][0] != '高雄市'"
#             ng-class="{'is-checked': searchCondition.mrt.indexOf(m.name) > -1 }"
#             ng-repeat="m in mrt.tp" class="mrt-chkbox" title="{{ m.name }}"
#             ng-style="m.css_coordinate"></span>
#
#       <span ng-show="searchCondition.addr[0][0] == '高雄市'"
#             ng-class="{'is-checked': searchCondition.mrt.indexOf(m.name) > -1 }"
#             ng-repeat="m in mrt.kh" class="mrt-chkbox" title="{{ m.name }}"
#             ng-style="m.css_coordinate"></span>
#     </div>
#
#     <a href class="arrow arrow-up"></a>
#     <a href class="arrow arrow-down"></a>
#   </div>
# </div>
#
# </div>
# <!-- 搜尋區塊 -->
#
#     <!-- 搜尋區塊 -->
#     <!-- 推薦物件 -->
#     <section class="m-main-block ng-scope">
#         <header class="main-block-hd has-line"><h2>本週必搶</h2></header>
#         <div class="main-block-bd">
#             <ul pagetype="buylist" class="l-item-list promo-list ng-isolate-scope is-loading"></ul>
#         </div>
#     </section>
#     <!-- 推薦物件 -->
#     <!-- 物件列表 -->
#     <div class="l-main-list">
#         <div class="list-hd-outer">
#             <div class="list-type">
#                 <a ga-buy-search ga-label="buy_function_list_button" ga-event="buy_function_click" ga-cat="buy_function" href="#" class="list-text active"><i class="fa fa-list-ul"></i> 列表</a>
#                 <a ga-buy-search ga-label="buy_function_map_button" ga-event="buy_function_click" ga-cat="buy_function" href="#" class="list-map"><i class="i-map"></i> 地圖</a>
#             </div>
#
#         </div>
#
#         <!-- <div class="list-filters"> -->
#         <div class="list-hd-inner">
#     <a href ga-buy-search ga-label="buy_filter_tag_none" ga-event="buy_filter_tag_click" ga-cat="buy_filter" filter="" class="list-filter is-first "><span>全部 (6646)</span></a>
#     <a href ga-buy-search ga-label="buy_filter_tag_new" ga-event="buy_filter_tag_click" ga-cat="buy_filter" filter="new" class="list-filter "><span>新上架 (854)</span></a>
#     <a href ga-buy-search ga-label="buy_filter_tag_reduction" ga-event="buy_filter_tag_click" ga-cat="buy_filter" filter="pricereduction" class="list-filter active"><span>降價 (2422)</span></a>
#
#     <div class="list-sort-type m-select-box-wrap">
#     <a href class="list-sort-handler m-select-box">預設排序</a>
#     <div class="m-select-box-option has-border arrow-right">
#         <a href class="list-sort-option label" data-od="" ga-buy-search ga-label="buy_sort_default" ga-event="buy_sort_click" ga-cat="buy_sort">預設排序</a>
#
#     <a href class="list-sort-option label" data-od="11" ga-buy-search ga-label="buy_sort_TotalPrice_LowtoHigh" ga-event="buy_sort_click" ga-cat="buy_sort">總價: <span class="right">低 → 高</span></a>
#     <a href class="list-sort-option label" data-od="21" ga-buy-search ga-label="buy_sort_SinglePrice_LowtoHigh" ga-event="buy_sort_click" ga-cat="buy_sort">單價: <span class="right">低 → 高</span></a>
#     <a href class="list-sort-option label" data-od="30" ga-buy-search ga-label="buy_sort_Discount_HightoLow" ga-event="buy_sort_click" ga-cat="buy_sort">降幅: <span class="right">高 → 低</span></a>
#     <a href class="list-sort-option label" data-od="40" ga-buy-search ga-label="buy_sort_BuildPin_HightoLow" ga-event="buy_sort_click" ga-cat="buy_sort">建坪: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label" data-od="50" ga-buy-search ga-label="buy_sort_HousePin_HightoLow" ga-event="buy_sort_click" ga-cat="buy_sort">主+陽: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label" data-od="61" ga-buy-search ga-label="buy_sort_Age_LowtoHigh" ga-event="buy_sort_click" ga-cat="buy_sort">屋齡: <span class="right">小 → 大</span></a>
#     <a href class="list-sort-option label" data-od="70" ga-buy-search ga-label="buy_sort_LandPin_HightoLow" ga-event="buy_sort_click" ga-cat="buy_sort">地坪: <span class="right">大 → 小</span></a>
#     <a href class="list-sort-option label" data-od="80" ga-buy-search ga-label="buy_sort_UpTime_HightoLow" ga-event="buy_sort_click" ga-cat="buy_sort">上架日期: <span class="right">新 → 舊</span></a>
#     </div>
# </div>
#
#
# </div>
#
#         <!-- 主列表 -->
#         <ul class="l-item-list">
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2206024" class="item-img ga_click_trace" title="大安捷運獨棟華廈 台北市大安區復興南路二段" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCsnGL0zsJYG7y0YbISTHvWUUuXC-q_77zrV2ivaqi4QmYe6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARMqHFDH9pHFQ&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="大安捷運獨棟華廈 台北市大安區復興南路二段"></a>
#     <div class="item-info">
#         <a href="/house/2206024" target="_blank" class="item-title ga_click_trace" title="大安捷運獨棟華廈 台北市大安區復興南路二段" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>大安捷運獨棟華廈　台北市大安區復興南路二段</h3></a>
#         <div class="item-description" ng-non-bindable>YC881217  一層一戶單純格局方正三面採光 各位網路上的貴賓您們好~~本案位在大安捷運站附近，復興南路二段１１１巷上，這個區域的房屋類型多為電梯大樓以及華廈組成的住宅區，在本案後方還有所謂的立委會館，所以在一直是大安捷運站周遭區域裡許多客戶所指名的靜巷華廈如果您目標是找使用３０坪以上又要近捷運，又要市中心還要看林蔭，那本物件您一定不能錯過屋主心態很好，只要您有意願房子有喜歡，儘管出價價格永遠不會是問題永慶幫您談物件特色1.本案獨棟邊間一層僅有一戶戶數不多所以非常的單純2.屋齡３４年外觀維護的讓您看不出來已30年3.內部格局配置房間皆在四周沒有浪費走道空間，所以可以多隔出和室來利用4.房間皆有開窗沒有暗房，採光跟通風都十分不錯，更重要的是兩套浴廁皆有對外窗這樣的條件很難得5.離大安捷運站步行約5分鐘可到，大安站為雙捷運線交會點，所以往來信義文湖線十分方便不需換車6.本案件面對著帶狀公園，窗外看出去即可看到公園綠蔭附近行情
# 1.瑞安街23巷24弄x號4樓 36.64坪成交90萬
# 2.復興南路二段78巷30弄x號15樓 47.55坪 成交90.2萬
# 3.復興南路二段111巷x號4樓(正樓上) 44.85坪 成交91.1萬
# 4.瑞安街23巷x號5樓 43.49坪 成交100萬
# 5.瑞安街111巷x號7樓17.06坪 成交93.7萬
# 歡迎您網路留言或直接撥打電話，我將馬上幫您安排賞屋</div>
#
#         <ul class="item-info-detail">
#             <li>電梯大樓</li>
#             <li>
# 35.4年            </li>
#             <li>
# 3 ~ 3 / 7樓            </li>
#             <li>土地 7.35坪</li>
#             <li>主+陽 32.70坪</li>
#             <li>建物 41.53坪</li>
#             <li>
# 3房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
#             </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>近捷運大安站</span>
#                         <span>近捷運科技大樓站</span>
#                         <span>有天然瓦斯</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">9.7%</div>
#             <div class="original-price"> 3,953 萬</div>
#         <div class="price"><span class="price-num">3,568</span> 萬</div>
#         <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="2e9fb924-cd5f-4356-969e-e98c370af312">追蹤物件</a>
#     </div>
# </li>
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2502216" class="item-img ga_click_trace" title="磺溪捷運景觀大戶 台北市士林區磺溪街" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCuVTk6Woz3ihu9PBAhtc5RfFY4Coy8cua7mt-rgYliMeYe6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARGfcIjHhQUn2c7xNLBq2wEz5g7yUgAJsCgRXKWm7Zt7bq1UZZePl-UOQozxW9-AYawXFxrrYnkCPV7hpFd7OgPc&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="磺溪捷運景觀大戶 台北市士林區磺溪街"></a>
#     <div class="item-info">
#         <a href="/house/2502216" target="_blank" class="item-title ga_click_trace" title="磺溪捷運景觀大戶 台北市士林區磺溪街" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>磺溪捷運景觀大戶　台北市士林區磺溪街</h3></a>
#         <div class="item-description" ng-non-bindable>YC949495  近蘭雅國小 家樂福 克強泳池 磺溪街特色介紹：
# 【交通】F永慶房屋7芝山店5製作0轉貼必究5！
# 芝山捷運站(約400公尺，步行約5分鐘)
# U-Bike自行車租借(約400公尺，步行約5分鐘)
# F永慶房屋7芝山店5製作0轉貼必究5！
# 【生活機能】F永慶房屋7芝山店5製作0轉貼必究5！
# SOGO百貨公司(約300公尺，步行約4分鐘)
# 家樂福(約200公尺，步行約3分鐘)
# 台灣戲曲中心(約600公尺，步行約7分鐘)
# 太古歐洲小學(約700公尺，步行約8分鐘)
# 法官學院.行政法院(約800公尺，步行約9分鐘)
# F永慶房屋7芝山店5製作0轉貼必究5！
# 【公園】F永慶房屋7芝山店5製作0轉貼必究5！
# 磺溪步道(約200公尺，步行約3分鐘)
# 萬坪水舞秀忠誠公園(約600公尺，步行約7分鐘)
# &#160;F永慶房屋7芝山店5製作0轉貼必究5！
# 【醫療】F永慶房屋7芝山店5製作0轉貼必究5！
# 新光醫院、振興醫院、陽明醫院、藍田月子中心、榮總醫院&#160;都不遠
# F永慶房屋7芝山店5製作0轉貼必究5！
# 歡迎來電看屋，委託售屋！
# 請指定在地最熟悉本區的 永慶房屋 芝山店^_^</div>
#
#         <ul class="item-info-detail">
#             <li>公寓</li>
#             <li>
# 29.0年            </li>
#             <li>
# 5 ~ 5 / 5樓            </li>
#             <li>土地 13.06坪</li>
#             <li>主+陽 33.31坪</li>
#             <li>建物 41.95坪</li>
#             <li>
# 3房(室)2廳2衛            </li>
#             <li>
# 加蓋 1房(室)0廳1衛            </li>
#             <li>
#             </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>磺溪逸庭</span>
#                         <span>近捷運芝山站</span>
#                         <span>近捷運明德站</span>
#                         <span>有天然瓦斯</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">5.2%</div>
#             <div class="original-price"> 2,480 萬</div>
#         <div class="price"><span class="price-num">2,350</span> 萬</div>
#         <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="2329844f-ccbc-4dd4-88d8-5f0050ee8145">追蹤物件</a>
#     </div>
# </li>
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2149601" class="item-img ga_click_trace" title="忠誠捷運四房車位 台北市士林區忠誠路一段" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCuU48ib9nhxx5dMZrIgEfDguG6g7jxinE3ZEenLYN2QCYe6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARMqHFDH9pHFQ&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="忠誠捷運四房車位 台北市士林區忠誠路一段"></a>
#     <div class="item-info">
#         <a href="/house/2149601" target="_blank" class="item-title ga_click_trace" title="忠誠捷運四房車位 台北市士林區忠誠路一段" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>忠誠捷運四房車位　台北市士林區忠誠路一段</h3></a>
#         <div class="item-description" ng-non-bindable>YC879116  忠誠路段稀有中庭管理4房坡車 忠誠捷運四房車位特色：
# 1.忠誠路門牌 的忠誠捷運四房車位
# 2.24小時中庭花園管理 的忠誠捷運四房車位
# 3.大坪數稀有坡道車位 的忠誠捷運四房車位
# 4.戶數單純 的忠誠捷運四房車位
# 5.無障礙空間 的忠誠捷運四房車位
# 永慶房屋為您提供業界最高規格的六大安心保障。
# １．產權七審（房屋產權審查詳細確認屋況保障交易安全）２．價金履約保障（由銀行進行履約保證開立專戶，買賣雙方交易更放心）３．漏水保固（業界唯一無屋齡限制，最高３０萬元的保固額度）４．凶宅保障（建立凶宅警示系統，購屋更安心）５．高輻射建物保障６．高氯離子建物保障&#160;
# &#160;
# 感謝天母在地住戶的大力支持!105年忠誠店、商圈成交實績(不含外區共累計成交共21戶)(1)105/02 &#160; 忠義街X號5樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交1110萬(2)105/02 &#160; 忠誠路一段173巷X號5樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交1030萬(3)105/02 &#160; 克強路10巷10弄X號2樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交1700萬(4)105/03 &#160; 德行東路X號4樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交1040萬(5)105/03 &#160; 忠義街71巷X號1樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交3125萬(6)105/03 &#160; 忠義街X號3樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交2210萬(7)105/03 &#160; 忠誠路二段10巷X號4樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交4250萬(8)105/03 &#160; 忠誠路一段X號8樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交2600萬(9)105/04 &#160; 忠誠路二段21巷X號5樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交1420萬(10)105/04 德行東路X號2樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交2850萬(11)105/04 忠誠路一段100巷15弄X號4樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交1680萬(12)105/05 至誠路二段X號4樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交1700萬(13)105/05 忠誠路二段X號10樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交4695萬(14)105/06 德行東路X號12樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交9050萬(15)105/07 福華路141巷X號1樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交1870萬(16)105/09 德行西路X號10樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 成交958萬(17)105/09 忠誠路一段16巷X號5樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交856萬(18)105/11 &#160;德行東路209巷X號2樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;成交1780萬(19)105/12 忠義街X號X樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;交屋手續中(20)105/12 忠誠路二段21巷X弄X號X樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 交屋手續中(21)105/12 中山北路五段X巷X號X樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 交屋手續中(22)106/01 忠誠路一段X號1樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 交屋手續中(23)106/02 忠誠路一段X號8樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 交屋手續中(24)106/02 德行東路X號4樓 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;交屋手續中(25)106/02 天母東路105巷X號4樓 &# ...
# 02-2833-0466
# &#160;
# 歡迎轉介紹、委託案件，交給忠誠店最專業的經紀人
# 『多角化行銷』，『最專業介紹』，『立即性回報』，『超感心服務』
# 提供給您最好的服務
# 1.免費代算增值稅
# 2.免費提供房地合一對您的影響分析
# 3.免費提供成交行情，針對內政部實價登錄，彙整後.依地點，樓層景觀，屋況提供最真實專業的行情資訊
# 4.免費介紹修繕廠商
# 5.免費提供好房誌
# 6.任何的房產資訊</div>
#
#         <ul class="item-info-detail">
#             <li>電梯大樓</li>
#             <li>
# 34.1年            </li>
#             <li>
# 2 ~ 2 / 7樓            </li>
#             <li>土地 12.24坪</li>
#             <li>主+陽 53.21坪</li>
#             <li>建物 70.31坪</li>
#             <li>
# 4房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位7.62坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>近捷運芝山站</span>
#                         <span>有天然瓦斯</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">15.3%</div>
#             <div class="original-price"> 5,888 萬</div>
#         <div class="price"><span class="price-num">4,990</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="92f31e97-2c97-4398-894b-7a5e9634b83a">追蹤物件</a>
#     </div>
# </li>
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2922447" class="item-img ga_click_trace" title="政大新婚首選兩房 台北市文山區指南路三段" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCvTTOmvYu4LCrZiA21feM03AwH8Ac3yGNCj9Otin5quO4e6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARMqHFDH9pHFQ&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="政大新婚首選兩房 台北市文山區指南路三段"></a>
#     <div class="item-info">
#         <a href="/house/2922447" target="_blank" class="item-title ga_click_trace" title="政大新婚首選兩房 台北市文山區指南路三段" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>政大新婚首選兩房　台北市文山區指南路三段</h3></a>
#         <div class="item-description" ng-non-bindable>YC976392  政大平面商圈高樓層稀有釋出 1.社區戶數單純,本戶為一層三戶,社區總戶數82戶2.北政國中政大附中明星雙學區3.稀有前陽台進出,還有後陽台,萬中選一4.政大平面商圈稀有釋出,不用上山,環境清幽,離塵不離城5.社區B1有垃圾集中,免追垃圾車免用專用垃圾袋,超級方便6.超低公設比優質社區,不到17%公設比7.廁所有開窗,非常通風8.高樓層無敵景觀視野 &#160;前看青山、後看整個重劃區
# 永慶房屋我們提供業界高規格服務品質及六大安心保障&#160; &#160; &#160;&#160;1.產權七審(房屋產權審查鉅細靡遺)2.價金履約保證(買賣成交價金，由銀行進行履約保障，買賣雙方更放心)3.漏水保固(無屋齡限制，最高30萬元的保固額度)4.凶宅保障(建立凶宅警示系統，購屋更安心)5.高輻射建物保障6.高氯離子建物保障
# &#160; 永慶房屋優勢
# &#160;
# 1.團隊雙北聯賣，一家委託多家聯賣，買方多效率快。2.雙網平台(永慶房仲網、好房網)，流量大，點閱率高。
# 2.成交行情公開:公開內部成交行情+實價登錄行情，為您把關。3.六大安心保障:六大安心，讓您交易過程完全放心和安心
# 4.服務業大評鑑五連霸奪連鎖房仲業冠軍。
# 歡迎來電預約看屋,我們會以最專業最熱忱的服務接待您</div>
#
#         <ul class="item-info-detail">
#             <li>電梯大樓</li>
#             <li>
# 20.9年            </li>
#             <li>
# 12 ~ 12 / 12樓            </li>
#             <li>土地 6.36坪</li>
#             <li>主+陽 17.52坪</li>
#             <li>建物 26.84坪</li>
#             <li>
# 2房(室)2廳1衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位5.92坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
# ...
#             <li>
# 5.0年            </li>
#             <li>
# 4 ~ 4 / 13樓            </li>
#             <li>土地 8.76坪</li>
#             <li>主+陽 35.66坪</li>
#             <li>建物 56.60坪</li>
#             <li>
# 2房(室)2廳2衛            </li>
#             <li>
#             </li>
#             <li>
# (含車位0.72坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>近捷運科技大樓站</span>
#                         <span>近捷運六張犁站</span>
#                         <span>有天然瓦斯</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">17.7%</div>
#             <div class="original-price"> 9,700 萬</div>
#         <div class="price"><span class="price-num">7,980</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="4b718b9a-b02d-4c8b-be7b-deae1dfd0761">追蹤物件</a>
#     </div>
# </li>
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2616503" class="item-img ga_click_trace" title="美麗華精品店面 台北市中山區敬業一路" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCu7d7P7qI71RgxkhBdOIsZf12n6ejX3XpORG_Muo7ykcoe6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARMqHFDH9pHFQ&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="美麗華精品店面 台北市中山區敬業一路"></a>
#     <div class="item-info">
#         <a href="/house/2616503" target="_blank" class="item-title ga_click_trace" title="美麗華精品店面 台北市中山區敬業一路" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>美麗華精品店面　台北市中山區敬業一路</h3></a>
#         <div class="item-description" ng-non-bindable>YC955209  美麗華捷運站旁純一樓精品店面 美麗華精品店面美麗華捷運站旁純一樓精品店面</div>
#
#         <ul class="item-info-detail">
#             <li>電梯大樓</li>
#             <li>
# 16.1年            </li>
#             <li>
# 1 ~ 1 / 7樓            </li>
#             <li>土地 27.11坪</li>
#             <li>主+陽 48.23坪</li>
#             <li>建物 89.35坪</li>
#             <li>
# 0房(室)0廳2衛            </li>
#             <li>
# 加蓋 1房(室)0廳0衛            </li>
#             <li>
# (含車位16.25坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>近捷運劍南路站</span>
#                         <span>大面寬</span>
#                         <span>正面大馬路</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">11.2%</div>
#             <div class="original-price"> 14,340 萬</div>
#         <div class="price"><span class="price-num">12,730</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="f9cd676d-b62d-45f7-8c19-0284db50bbe1">追蹤物件</a>
#     </div>
# </li>
#
#
#
#
# <li class="m-list-item">
#     <a href="/house/2600266" class="item-img ga_click_trace" title="風光河景樓中樓 台北市文山區新光路一段" target="_blank" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_info_photo_main"><img src="//fps.hfcdn.com/v1/image/?key=NF58Ko5oaCuuTqfTKGfOz02wRqgJ_KzGGZqPhinnPVZXsJnSV6gb8oe6hKQhd2KYzhxlNAx_tGVI54tDXXIxDa64od0jAbOZrBTGt_NC0NxMCtyFz-LqpYF32GTxpmDwu98NT3cksTOdfCdPPdyK135VIFHrez70Z1VcJ8bRa7pm3HmW7PiaW7ylr-jBCtQwuvapXmyoUPkbEis8iAdARMqHFDH9pHFQ&amp;width=240&amp;height=180" onerror="this.src='/Content/img/non-photo.png';" alt="風光河景樓中樓 台北市文山區新光路一段"></a>
#     <div class="item-info">
#         <a href="/house/2600266" target="_blank" class="item-title ga_click_trace" title="風光河景樓中樓 台北市文山區新光路一段" ga_cat="buy_list" ga_event="buy_list_click" ga_label="buy_list_title"><h3>風光河景樓中樓　台北市文山區新光路一段</h3></a>
#         <div class="item-description" ng-non-bindable>YC952319  正面河景 背對山景 一層一戶 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;政大水岸 &#160;景觀樓中樓豪邸 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;物件特色
# 1.270度環繞景觀&#160;:&#160;正面河岸景觀&#160;後面樹海山景&#160;遠眺台北101景觀&#160;&#160;想擁有生活機&#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; 能 又要有隱私的絕佳選擇(室內所空間看出去都是天然美景)
# 2.挑搞空間&#160;:增加室內的空間感&#160;+大片窗戶設計 在家裡 不用刻意去看&#160;景觀就&#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;會自己佔據您的視線
# 3.一層一戶:&#160;一層一戶 豪宅規格
# 4.增建空間大:&#160;除了權狀上的空間:室內還有機房回饋空間和梯廳的使用+夾層增建 &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160; &#160;+露台空間
# 5.採光佳:&#160;邊間 採光 加上挑高設計 光線更可以灑在室內
# &#160;外在環境1.近捷運站:走路到捷運站約10分鐘(參考google&#160;map)
# 2.交通便利:除了多線公車 開車可以直上信義快北二高 超方便
# 3.河濱公園:休閒運動超方便
# 4.政大附中學區:&#160;學區優勢 又不用上山
# 5.未來性佳:&#160;政大大學城規劃 還有未來捷運站&#160;</div>
#
#         <ul class="item-info-detail">
#             <li>電梯大樓</li>
#             <li>
# 4.9年            </li>
#             <li>
# 10 ~ 10 / 10樓            </li>
#             <li>土地 15.01坪</li>
#             <li>主+陽 49.51坪</li>
#             <li>建物 96.43坪</li>
#             <li>
# 4房(室)2廳3衛            </li>
#             <li>
# 加蓋 4房(室)1廳1衛            </li>
#             <li>
# (含車位8.26坪)            </li>
#         </ul>
#
#         <div class="item-tags">
#                 <div class="vr-tag--rectangle"><div class="vr-icon"></div></div>
#             <i class="fa fa-tags"></i>
#                                                 <span>風光</span>
#                         <span>近捷運木柵站</span>
#                         <span>近捷運動物園站</span>
#                         <span>有天然瓦斯</span>
#         </div>
#     </div>
#
#     <div class="item-price">
#             <div class="reduce-rate">9.8%</div>
#             <div class="original-price"> 7,980 萬</div>
#         <div class="price"><span class="price-num">7,200</span> 萬</div>
# <div class="sub-price">(含車位價)</div>        <div class="sub-price"></div>
#         <a ga-buy-search ga-cat="buy_list" ga-event="buy_list_click" ga-label="buy_list_fav" href class="save-not-login-btn save-item-btn" data-favo data-favo-pop data-caseid="7f6cb635-3151-43de-858a-1f512ee51c26">追蹤物件</a>
#     </div>
# </li>
#         </ul>
#         <div class="search-list-not-found"></div>
#             <div class="m-pagination">
#         <ul class="m-pagination-bd">
#             <li class="is-disabled"><a href="" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_first">第一頁</a></li>
#             <li class="is-disabled"><a href="" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_pre">&lt; 上一頁 </a></li>
#                     <li class="is-active"><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=1" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_1">1</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=2" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_2">2</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=3" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_3">3</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=4" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_4">4</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=5" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_5">5</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=6" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_6">6</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=7" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_7">7</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=8" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_8">8</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=9" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_9">9</a></li>
#                     <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=10" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_10">10</a></li>
#             <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=2" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_next">下一頁 &gt;</a></li>
#             <li class=""><a href="/region/%E5%8F%B0%E5%8C%97%E5%B8%82-_c/pricereduction_filter/?pg=122" class="ga_click_trace" ga_cat="buy_page" ga_event="buy_page_click" ga_label="buy_page_last">最末頁</a></li>
#         </ul>
#     </div>
#
#     </div>
#     <div class="m-ad-banner">
#         <script language="javascript" type="text/javascript" src="//admd.yungching.com.tw/LAYOUT.aspx?ID=80.F033AB37C30201F73F142449D037028D"></script>
#     </div>
# </main>
#     <script src="/Scripts/libs/jquery-1.11.1.min.js"></script>
#
#
#
# <div class="cirobox is-hide" tabindex="-1" role="dialog">
#     <div class="cirobox-hd">
#         <a style="top: 10px;" title="關閉" href="javascript:;" class="cirobox-icon-close"><i>&times;</i></a>
#     </div>
#     <div class="cirobox-bd"></div>
# </div>
#
# <script src="/Scripts/libs/cirobox.js"></script>
# <script>
#     var openLightbox = function (e) {
#         e.preventDefault();
#         var _this = $(this);
#         var cheight = 400,
#             cwidth = 700;
#         if (_this.data('cheight')) cheight = _this.data('cheight');
#         if (_this.data('cwidth')) cwidth = _this.data('cwidth');
#         _this.CiRoBox({
#             click: false,
#             url: _this.attr('href'),
#             width: cwidth,
#             height: cheight,
#             closeafter: function () {
#                 $('.cirobox-bd').html('');
#                 $('.cirobox-bd').attr('style', '');
#             },
#             openafter: function () {
#
#                 if (_this.hasClass('m-btn-notice')) {
#                     $('.cirobox-bd').attr({
#                         'style': 'padding: 0.5em 1em'
#                     });
#                     if ($('.cirobox-bd .bd-title').length < 1) {
#                         $('.cirobox-bd').prepend('<div class="bd-wrap" style="border-bottom: 1px solid #e2e2e2;"><h3 class="bd-title">' + _this.data('title') + '</h3></div>');
#                     }
#                 }
#
#                 var cbIframeHeight = 0;
#                 $(window).on('message', function (e) {
#                     if (e.originalEvent.origin.indexOf('yungching.com.tw') > -1) {
#                         if (e.originalEvent.data === 'closeBox') {
#                             $.CiRoBox.close();
#                         } else if (!isNaN(parseInt(e.originalEvent.data, 10)) && cbIframeHeight !== e.originalEvent.data) {
#                             cbIframeHeight = parseInt(e.originalEvent.data, 10);
#                             $('.cirobox, .cirobox iframe').height(cbIframeHeight);
#                             $.CiRoBox.resize(700, cbIframeHeight);
#                         }
#                     }
#                 });
#             }
#         });
#     };
#     $('.openLightbox').on('click', openLightbox);
#
#     (function () {
#         var marquee = $('.header-marquee-bd'),
#             cnt = 0,
#             marqueeCnt = marquee.children('li').length,
#             rotate;
#
#         if (marqueeCnt > 0) {
#             var setRotate = function () {
#                 rotate = setInterval(function () {
#                     if (++cnt >= marqueeCnt) cnt = 0;
#
#                     if ($('html').hasClass('no-csstransforms')) {
#                         marquee.css({
#                             'top': (-26 * cnt) + 'px'
#                         });
#                     } else {
#                         marquee.css({
#                             'transform': 'translate(0, ' + (-26 * cnt) + 'px)'
#                         });
#                     }
#                 }, 3450);
#             };
#             setRotate();
#
#             marquee.on({
#                 'mouseenter': function () {
#                     window.clearInterval(rotate);
#                 },
#                 'mouseleave': function () {
#                     window.clearInterval(rotate);
#                     setRotate();
#                 }
#             });
#         }
#     }());
#
#     (function () {
#         // 未登入且收藏數 0
#         var isLogin = ($('#hiddentopmbid').length === 0) ? true : ($('#hiddentopmbid').val() === "") ? false : true;
#         var $cnt = $('.l-header .m-header-bar .m-header-bar-bd .m-badge'), cnt = parseInt($cnt.text(), 10) || 0;
#         var urlHost = (document.location.host.indexOf('-t') > 0) ? 'memberyc-t' : (document.location.host.indexOf('-s') > 0) ? 'memberyc-s' : 'memberyc';
#         if (!isLogin && cnt === 0) {
#
#             $cnt.parent().removeClass('ga_click_trace').off('click').on('click', function (e) {
#                 e.preventDefault();
#
#                 var iframe = document.createElement('iframe');
#                 var htmlStr = [];
#
#                 htmlStr.push('<div class="lb-ins">');
#                 htmlStr.push('<div class="lb-title"><h3>收藏</h3></div>');
#
#                 htmlStr.push('<div class="lb-content"><div class="l-unlogin" id="unlogin">');
#                 htmlStr.push('<p>您尚未登入會員，請先<a target="_top" href="https://' + urlHost + '.yungching.com.tw/Account/Login?MBSourceID=108&AFromURL=' + window.location.href + '">登入</a>。</p>');
#                 htmlStr.push('<p>若您還不是會員請先<a target="_top" href="https://' + urlHost + '.yungching.com.tw/Account/SignUp?AccountPattern=Mobile&MBSourceID=108">加入會員</a>。</p>');
#                 htmlStr.push('</div></div>');
#
#                 $(this).CiRoBox({
#                     click: false,
#                     keyboardclose: false,
#                     backdropclose: true,
#                     width: 570,
#                     height: 155,
#                     content: htmlStr.join('')
#                 });
#                 return false;
#             });
#         }
#     })();
# </script>
#
#     <footer class="l-footer">
#         <script type="text/javascript" src="//s1.hfcdn.com/min/b=fp/yc_common&f=footer.js&v=20180123001"></script>
#     </footer>
#
#     <script>
#     var timer;
#     var _searchCondition = {
#       "searchFor": '',
#       "mainType": 'region',
#       "addr": [
#         ['%e5%8f%b0%e5%8c%97%e5%b8%82'],
#         ['']
#       ],
#       "mrt":[],
#       "isMap": false,
#       "price": [],
#       "pyeong": [],
#       "keywords": [''],
#       "filterBy": ['pricereduction'],
#       "sortBy": [],
#       "advConditions": {
#           "car": [],
#           "houseType": [],
#           "accessible": [],
#           "houseAge": [],
#           "directions": [],
#           "floors": {
#               "sp": ["false"],
#           "val": []
#           },
#           "rooms": {
#               "sp": ["false"],
#               "val": []
#           }
#       }
#     };
#
#     </script>
#
#
#
#     <script src="/bundles/searchjs?v=wHYlWdOD4IDvSTq7rqWxqb-7iIAugSVEQVkQDKNs6fw1"></script>
#
#
#
#
# </body>
# </html>

# %%
res.request.headers
# Out:
# {'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.76 Safari/537.36', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': 'cookiesession1=68C4953EMOWO4DG1FMVQ7RJH1PBV04EE'}
