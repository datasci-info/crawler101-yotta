# %%
import os

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'pybasic_functions.ipynb',
#  'pybasic_iterators.ipynb',
#  'pybasic_os.ipynb',
#  'pybasic_string.ipynb']

# %%
os.mkdir("test")

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'pybasic_functions.ipynb',
#  'pybasic_iterators.ipynb',
#  'pybasic_os.ipynb',
#  'pybasic_string.ipynb',
#  'test']

# %%
os.removedirs("test")

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'pybasic_functions.ipynb',
#  'pybasic_iterators.ipynb',
#  'pybasic_os.ipynb',
#  'pybasic_string.ipynb']
